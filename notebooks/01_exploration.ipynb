# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from core.data import load_from_kaggle

# %%
dataset_link = "shriyashjagtap/esg-and-financial-performance-dataset" # replace with your dataset link from Kaggle 
destination = "../data/raw"
dataset_name = dataset_link.split("/")[-1]

files = load_from_kaggle(
    dataset_link=dataset_link, 
    destination=destination,
    )
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/shriyashjagtap/esg-and-financial-performance-dataset?dataset_version_number=1...
# 100%|██████████| 379k/379k [00:00<00:00, 1.57MB/s]
# Extracting files...
# Loading dataset from C:\Users\Trainee\.cache\kagglehub\datasets\shriyashjagtap\esg-and-financial-performance-dataset\versions\1 to ../data/raw\esg-and-financial-performance-dataset
# Moving file: C:\Users\Trainee\.cache\kagglehub\datasets\shriyashjagtap\esg-and-financial-performance-dataset\versions\1\company_esg_financial_dataset.csv to c:\Users\Trainee\Desktop\DPP_Projekte\DPP-2026_Julian\notebooks\../data/raw\esg-and-financial-performance-dataset
# Files moved to '../data/raw\esg-and-financial-performance-dataset' directory.

# %%
files
# Out:
# ['company_esg_financial_dataset.csv']

# %%
df = pd.read_csv("/".join(["../data/raw/", dataset_name, files[0]]))
df.head()
# Out:
#    CompanyID CompanyName Industry         Region  Year  Revenue  ProfitMargin  \
# 0          1   Company_1   Retail  Latin America  2015    459.2           6.0
# 1          1   Company_1   Retail  Latin America  2016    473.8           4.6
# 2          1   Company_1   Retail  Latin America  2017    564.9           5.2
# 3          1   Company_1   Retail  Latin America  2018    558.4           4.3
# 4          1   Company_1   Retail  Latin America  2019    554.5           4.9
#
#    MarketCap  GrowthRate  ESG_Overall  ESG_Environmental  ESG_Social  \
# 0      337.5         NaN         57.0               60.7        33.5
# 1      366.6         3.2         56.7               58.9        32.8
# 2      313.4        19.2         56.5               57.6        34.0
# 3      283.0        -1.1         58.0               62.3        33.4
# 4      538.1        -0.7         56.6               63.7        30.0
#
#    ESG_Governance  CarbonEmissions  WaterUsage  EnergyConsumption
# 0            76.8          35577.4     17788.7            71154.7
# 1            78.5          37314.7     18657.4            74629.4
# 2            77.8          45006.4     22503.2            90012.9
# 3            78.3          42650.1     21325.1            85300.2
# 4            76.1          41799.4     20899.7            83598.8

# %%
display(
    "Shape",
    df.shape,
    "Description",
    df.describe().round(2).T,
    "Duplicates",
    df.duplicated().sum(),
)


pd.DataFrame(
    {
        "Data Types": df.dtypes,
        "Missing Values": df.isnull().sum(),
        "Unique Values": df.nunique(),
        "Sample Values": [df[col].sample(3).tolist() for col in df.columns]
    })
# Out:
# 'Shape'
# (11000, 16)
# 'Description'
#                      count         mean          std     min        25%  \
# CompanyID          11000.0       500.50       288.69     1.0     250.75
# Year               11000.0      2020.00         3.16  2015.0    2017.00
# Revenue            11000.0      4670.85      9969.95    35.9     938.78
# ProfitMargin       11000.0        10.90         8.76   -20.0       5.30
# MarketCap          11000.0     13380.62     39922.87     1.8    1098.52
# GrowthRate         10000.0         4.83         9.42   -36.0      -1.32
# ESG_Overall        11000.0        54.62        15.89     6.3      44.10
# ESG_Environmental  11000.0        56.42        26.77     0.0      34.70
# ESG_Social         11000.0        55.66        23.36     0.0      37.60
# ESG_Governance     11000.0        51.77        25.32     0.0      30.78
# CarbonEmissions    11000.0   1271462.35   5067760.30  2042.2  122852.95
# WaterUsage         11000.0    560044.15   1565686.22  1021.1   64884.68
# EnergyConsumption  11000.0  11658393.75  50958356.02  5105.5  306916.12
#
#                           50%         75%           max
# CompanyID              500.50      750.25  1.000000e+03
# Year                  2020.00     2023.00  2.025000e+03
# Revenue               1902.30     4342.62  1.808104e+05
# ProfitMargin            10.50       16.30  5.000000e+01
# MarketCap             3096.45     9995.50  8.652717e+05
# GrowthRate               4.90       11.00  3.800000e+01
# ESG_Overall             54.60       65.60  9.880000e+01
# ESG_Environmental       55.60       79.00  1.000000e+02
# ESG_Social              55.15       73.80  1.000000e+02
# ESG_Governance          52.10       73.00  1.000000e+02
# CarbonEmissions     292073.45   740731.12  1.741047e+08
# WaterUsage          203880.45   525187.98  5.223142e+07
# EnergyConsumption  1221745.45  5616436.72  1.741047e+09
# 'Duplicates'
# np.int64(0)
#                   Data Types  Missing Values  Unique Values  \
# CompanyID              int64               0           1000
# CompanyName           object               0           1000
# Industry              object               0              9
# Region                object               0              7
# Year                   int64               0             11
# Revenue              float64               0           9965
# ProfitMargin         float64               0            536
# MarketCap            float64               0          10385
# GrowthRate           float64            1000            562
# ESG_Overall          float64               0            823
# ESG_Environmental    float64               0            991
# ESG_Social           float64               0            966
# ESG_Governance       float64               0            995
# CarbonEmissions      float64               0          10994
# WaterUsage           float64               0          10986
# EnergyConsumption    float64               0          10997
#
#                                                 Sample Values
# CompanyID                                     [176, 566, 104]
# CompanyName             [Company_107, Company_18, Company_19]
# Industry           [Manufacturing, Manufacturing, Healthcare]
# Region                               [Africa, Africa, Africa]
# Year                                       [2016, 2022, 2020]
# Revenue                              [2198.1, 1319.8, 4543.5]
# ProfitMargin                                [8.6, 17.5, 16.6]
# MarketCap                             [481.9, 78802.9, 995.4]
# GrowthRate                                   [-8.7, 0.4, 4.7]
# ESG_Overall                                [49.1, 35.1, 43.4]
# ESG_Environmental                          [18.4, 71.8, 53.7]
# ESG_Social                                [31.9, 87.2, 100.0]
# ESG_Governance                             [83.9, 75.8, 76.8]
# CarbonEmissions                [284575.8, 703195.4, 260777.3]
# WaterUsage                     [317234.5, 239910.1, 717614.5]
# EnergyConsumption           [1022498.9, 2391583.9, 5196049.2]

# %%
fig, ax = plt.subplots(figsize=(12, 10), dpi=200)

sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", center=0, ax=ax);
